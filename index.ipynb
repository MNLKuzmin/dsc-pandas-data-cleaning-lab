# %% [markdown]
# # Pandas Data Cleaning - Cumulative Lab
#
# ## Introduction
# In this lab, we'll make use of everything we've learned about pandas, data cleaning, and exploratory data analysis. In order to complete this lab, you'll have to import, clean, combine, reshape, and visualize data to answer questions provided, as well as your own questions!
#
# ## Objectives
# You will be able to:
# - Practice opening and inspecting the contents of CSVs using pandas dataframes
# - Practice identifying and handling missing values
# - Practice identifying and handling invalid values
# - Practice cleaning text data by removing whitespace and fixing typos
# - Practice joining multiple dataframes

# %% [markdown]
# ## Your Task: Clean the Superheroes Dataset with Pandas
#
# ![LEGO superheroes](images/lego_superheroes.jpg)
#
# Photo by <a href="https://unsplash.com/@yuliamatvienko?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Yulia Matvienko</a> on <a href="/s/photos/superhero?utm_source=unsplash&utm_medium=referral&utm_content=creditCopyText">Unsplash</a>

# %% [markdown]
# ### Data Understanding
# In this lab, we'll work with a version of the comprehensive Superheroes Dataset, which can be found on [Kaggle](https://www.kaggle.com/claudiodavi/superhero-set/data) and was originally scraped from [SuperHeroDb](https://www.superherodb.com/). We have modified the structure and contents of the dataset somewhat for the purposes of this lab.  Note that this data was collected in June 2017, so it may not reflect the most up-to-date superhero lore.
#
# The data is contained in two separate CSV files:
#
# 1. `heroes_information.csv`: each record represents a superhero, with attributes of that superhero (e.g. eye color). Height is measured in centimeters, and weight is measured in pounds.
# 2. `super_hero_powers.csv`: each record represents a superpower, then has True/False values representing whether each superhero has that power
#
# ### Business Understanding
#
# The business questions you have been provided are:
#
# 1. What is the distribution of superheroes by publisher?
# 2. What is the relationship between height and number of superpowers? And does this differ based on gender?
# 3. What are the 5 most common superpowers in Marvel Comics vs. DC Comics?
#
# This lab also simulates something you are likely to encounter at some point or another in your career in data science: someone has given you access to a dataset, as well as a few questions, and has told you to "find something interesting".
#
# So, in addition to completing the basic data cleaning tasks and the aggregation and reshaping tasks needed to answer the provided questions, you will also need to formulate a question of your own and perform any additional cleaning/aggregation/reshaping that is needed to answer it.

# %% [markdown]
# ### Requirements
#
# #### 1. Load the Data with Pandas
#
# Create a dataframes `heroes_df` and `powers_df` that represent the two CSV files. Use pandas methods to inspect the shape and other attributes of these dataframes.
#
# #### 2. Perform Data Cleaning Required to Answer First Question
#
# The first question is: *What is the distribution of superheroes by publisher?*
#
# In order to answer this question, you will need to:
#
# * Identify and handle missing values
# * Identify and handle text data requiring cleaning
#
# #### 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# The second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# In order to answer this question, you will need to:
#
# * Join the dataframes together
# * Identify and handle invalid values
#
# #### 4. Perform Data Aggregation Required to Answer Third Question
#
# The third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# This should not require any additional data cleaning or joining of tables, but it will require some additional aggregation.
#
# #### 5. Formulate and Answer Your Own Question
#
# This part is fairly open-ended. Think of a question that can be answered with the available data, and perform any cleaning or aggregation required to answer that question.

# %% [markdown]
# ## 1. Load the Data with Pandas
#
# In the cell below, we:
#
# * Import and alias `pandas` as `pd`
# * Import and alias `numpy` as `np`
# * Import and alias `seaborn` as `sns`
# * Import and alias `matplotlib.pyplot` as `plt`
# * Set Matplotlib visualizations to display inline in the notebook

# %%
# Run this cell without changes

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Superheroes
#
# In the cell below, load `heroes_information.csv` as `heroes_df`:

# %%
# Your code here
heroes_df=pd.read_csv('heroes_information.csv')
heroes_df.head()
# Out:
#    Unnamed: 0         name Gender Eye color               Race Hair color  \
# 0           0       A-Bomb   Male    yellow              Human    No Hair
# 1           1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair
# 2           2     Abin Sur   Male      blue            Ungaran    No Hair
# 3           3  Abomination   Male     green  Human / Radiation    No Hair
# 4           4      Abraxas   Male      blue      Cosmic Entity      Black
#
#    Height          Publisher Skin color Alignment  Weight
# 0   203.0      Marvel Comics          -      good   441.0
# 1   191.0  Dark Horse Comics       blue      good    65.0
# 2   185.0          DC Comics        red      good    90.0
# 3   203.0      Marvel Comics          -       bad   441.0
# 4   -99.0      Marvel Comics          -       bad   -99.0

# %% [markdown]
# It looks like that CSV came with an index column, resulting in an extra column called `Unnamed: 0`. We don't need that column, so write code to get rid of it below.
#
# There are two ways to do this:
#
# 1. Re-load with `read_csv`, and specify the parameter `index_col=0`
# 2. Drop the column `Unnamed: 0` with `axis=1`

# %%
# Your code here
heroes_df=pd.read_csv('heroes_information.csv',index_col=0)
heroes_df.head()
# Out:
#           name Gender Eye color               Race Hair color  Height  \
# 0       A-Bomb   Male    yellow              Human    No Hair   203.0
# 1   Abe Sapien   Male      blue      Icthyo Sapien    No Hair   191.0
# 2     Abin Sur   Male      blue            Ungaran    No Hair   185.0
# 3  Abomination   Male     green  Human / Radiation    No Hair   203.0
# 4      Abraxas   Male      blue      Cosmic Entity      Black   -99.0
#
#            Publisher Skin color Alignment  Weight
# 0      Marvel Comics          -      good   441.0
# 1  Dark Horse Comics       blue      good    65.0
# 2          DC Comics        red      good    90.0
# 3      Marvel Comics          -       bad   441.0
# 4      Marvel Comics          -       bad   -99.0

# %% [markdown]
# The following code checks that the dataframe was loaded correctly.

# %%
# Run this cell without changes

# There should be 734 rows
assert heroes_df.shape[0] == 734

# There should be 10 columns. If this fails, make sure you got rid of
# the extra index column
assert heroes_df.shape[1] == 10

# These should be the columns
assert list(heroes_df.columns) == ['name', 'Gender', 'Eye color', 'Race',
 'Hair color', 'Height', 'Publisher', 'Skin color', 'Alignment', 'Weight']

# %% [markdown]
# Now you want to get familiar with the data.  This step includes:
#
# * Understanding the dimensionality of your dataset
# * Investigating what type of data it contains, and the data types used to store it
# * Discovering how missing values are encoded, and how many there are
# * Getting a feel for what information it does and doesn't contain
#
# In the cell below, inspect the overall shape of the dataframe:

# %%
# Your code here
heroes_df.shape
# Out:
# (734, 10)

# %% [markdown]
# Now let's look at the info printout:

# %%
# Run this cell without changes
heroes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 734 entries, 0 to 733
# Data columns (total 10 columns):
# name          734 non-null object
# Gender        734 non-null object
# Eye color     734 non-null object
# Race          734 non-null object
# Hair color    734 non-null object
# Height        734 non-null float64
# Publisher     719 non-null object
# Skin color    734 non-null object
# Alignment     734 non-null object
# Weight        732 non-null float64
# dtypes: float64(2), object(8)
# memory usage: 63.1+ KB

# %% [markdown]
# In the cell below, interpret that information. Do the data types line up with what we expect? Are there any missing values?

# %%
# Replace None with appropriate text
"""
The data types seem appropriate, as the only 2 values which are numeric are float type.
There are a few missing values in the columns Publisher (15 values) and 2 missing values in the column Weight
"""
# Out:
# '\nThe data types seem appropriate, as the only 2 values which are numeric are float type.\nThere are a few missing values in the columns Publisher (15 values) and 2 missing values in the column Weight\n'

# %% [markdown]
# ### Superpowers
#
# Now, repeat the same process with `super_hero_powers.csv`. Name the dataframe `powers_df`. This time, make sure you use `index_col=0` when opening the CSV because the index contains important information.

# %%
# Your code here (create more cells as needed)
powers_df=pd.read_csv('super_hero_powers.csv',index_col=0)
powers_df.head()
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
#
#                        Agent Bob  ...    Wonder Man  Wonder Woman   X-23  \
# Agility                    False  ...         False         False   True
# Accelerated Healing        False  ...         False          True   True
# Lantern Power Ring         False  ...         False         False  False
# Dimensional Awareness      False  ...         False         False  False
# Cold Resistance            False  ...         False         False  False
#
#                        X-Man  Yellowjacket  Yellowjacket II   Ymir   Yoda  \
# Agility                False         False            False  False   True
# Accelerated Healing    False         False            False  False  False
# Lantern Power Ring     False         False            False  False  False
# Dimensional Awareness  False         False            False  False  False
# Cold Resistance        False         False            False   True  False
#
#                        Zatanna   Zoom
# Agility                  False  False
# Accelerated Healing      False  False
# Lantern Power Ring       False  False
# Dimensional Awareness    False  False
# Cold Resistance          False  False
#
# [5 rows x 667 columns]

# %% [markdown]
# The following code will check if it was loaded correctly:

# %%
# Run this cell without changes

# There should be 167 rows, 667 columns
assert powers_df.shape == (167, 667)

# The first column should be '3-D Man'
assert powers_df.columns[0] == '3-D Man'

# The last column should be 'Zoom'
assert powers_df.columns[-1] == 'Zoom'

# The first index should be 'Agility'
assert powers_df.index[0] == 'Agility'

# The last index should be 'Omniscient'
assert powers_df.index[-1] == 'Omniscient'

# %% [markdown]
# ## 2. Perform Data Cleaning Required to Answer First Question
#
# Recall that the first question is: *What is the distribution of superheroes by publisher?*
#
# To answer this question, we will only need to use `heroes_df`, which contains the `Publisher` column.
#
# ### Identifying and Handling Missing Values
#
# As you likely noted above, the `Publisher` column is missing some values. Let's take a look at some samples with and without missing publisher values:

# %%
# Run this cell without changes
has_publisher_sample = heroes_df[heroes_df["Publisher"].notna()].sample(5, random_state=1)
has_publisher_sample
# Out:
#            name  Gender Eye color   Race        Hair color  Height  \
# 60      Banshee    Male     green  Human  Strawberry Blond   183.0
# 61       Bantam    Male     brown      -             Black   165.0
# 219  DL Hawkins    Male         -      -                 -   -99.0
# 650       Synch    Male     brown      -             Black   180.0
# 8      Agent 13  Female      blue      -             Blond   173.0
#
#          Publisher Skin color Alignment  Weight
# 60   Marvel Comics          -      good    77.0
# 61   Marvel Comics          -      good    54.0
# 219   NBC - Heroes          -      good   -99.0
# 650  Marvel Comics          -      good    74.0
# 8    Marvel Comics          -      good    61.0

# %%
# Run this cell without changes
missing_publisher_sample = heroes_df[heroes_df["Publisher"].isna()].sample(5, random_state=1)
missing_publisher_sample
# Out:
#                  name  Gender Eye color    Race Hair color  Height Publisher  \
# 175      Chuck Norris    Male         -       -          -   178.0       NaN
# 286          Godzilla       -         -   Kaiju          -   108.0       NaN
# 263      Flash Gordon    Male         -       -          -   -99.0       NaN
# 138        Brundlefly    Male         -  Mutant          -   193.0       NaN
# 381  Katniss Everdeen  Female         -   Human          -   -99.0       NaN
#
#     Skin color Alignment  Weight
# 175          -      good   -99.0
# 286       grey       bad     NaN
# 263          -      good   -99.0
# 138          -         -   -99.0
# 381          -      good   -99.0

# %% [markdown]
# What do we want to do about these missing values?
#
# Recall that there are two general strategies for dealing with missing values:
#
# 1. Fill in missing values (either using another value from the column, e.g. the mean or mode, or using some other value like "Unknown")
# 2. Drop rows with missing values
#
# Write your answer below, and explain how it relates to the information we have:

# %%
# Replace None with appropriate text
"""
I would not drop the rows, since the publisher is the only information missing and that would mean discarding all the
other useful data from all the other values for each superhero.
I think generating the publisher from the other columns doesn't make a lot of sense, as it would be a complete guess
not being a numeric number, the risk is to just input wrong information (even if statistically correct, but ultimately
wrong unless we luckily get them all right). So I would go with just substituting the NaN with the value "Unknown" and
make this its own category. At that point I can study the distribution of the rest of the values with confidence,
knowing those are all true and correct.
"""
# Out:
# '\nI would not drop the rows, since the publisher is the only information missing and that would mean discarding all the\nother useful data from all the other values for each superhero.\nI think generating the publisher from the other columns doesn\'t make a lot of sense, as it would be a complete guess\nnot being a numeric number, the risk is to just input wrong information (even if statistically correct, but ultimately\nwrong unless we luckily get them all right). So I would go with just substituting the NaN with the value "Unknown" and\nmake this its own category. At that point I can study the distribution of the rest of the values with confidence,\nknowing those are all true and correct.\n'

# %% [markdown]
# Now, implement your chosen strategy using code. (You can also check the solution branch for the answer to the question above if you're really not sure.)

# %%
# Your code here
heroes_df['Publisher'].fillna('Unknown',inplace=True)

# %% [markdown]
# Now there should be no missing values in the publisher column:

# %%
# Run this cell without changes
assert heroes_df["Publisher"].isna().sum() == 0

# %% [markdown]
# ### Identifying and Handling Text Data Requiring Cleaning
#
# The overall field of natural language processing (NLP) is quite broad, and we're not going to get into any advanced text processing, but it's useful to be able to clean up minor issues in text data.
#
# Let's take a look at the counts of heroes grouped by publisher:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        379
# DC Comics            212
# NBC - Heroes          19
# Dark Horse Comics     18
# Unknown               15
# Image Comics          14
# George Lucas          14
# Marvel                 9
# HarperCollins          6
# Star Trek              6
# Team Epic TV           5
# SyFy                   5
# Icon Comics            4
# ABC Studios            4
# Shueisha               4
# IDW Publishing         4
# Wildstorm              3
#  DC Comics             3
# Sony Pictures          2
# South Park             1
# Microsoft              1
# J. R. R. Tolkien       1
# Rebellion              1
# J. K. Rowling          1
# Titan Books            1
# Hanna-Barbera          1
# Universal Studios      1
# Name: Publisher, dtype: int64

# %% [markdown]
# There are two cases where we appear to have data entry issues, and publishers that should be encoded the same have not been. In other words, there are four categories present that really should be counted as two categories (and you do not need specific comic book knowledge to be able to identify them).
#
# Identify those two cases below:

# %%
# Replace None with appropriate text
"""
The 4 entries are "Marvel Comics", 'Marvel', and 'DC Comics',' DC Comics'. Clearly due to typos/different spelling 
these have been separated in 4 different categories but really should just be two, 'Marvel Comics' and 'DC Comics'
"""
# Out:
# '\nThe 4 entries are "Marvel Comics", \'Marvel\', and \'DC Comics\',\' DC Comics\'. Clearly due to typos/different spelling \nthese have been separated in 4 different categories but really should just be two, \'Marvel Comics\' and \'DC Comics\'\n'

# %% [markdown]
# Now, write some code to handle these cases. If you're not sure where to start, look at the pandas documentation for [replacing values](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.replace.html) and [stripping off whitespace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.strip.html).

# %%
# Your code here
heroes_df.replace({'Marvel':'Marvel Comics'}, inplace=True)

# %%
heroes_df['Publisher']=[publ.strip() for publ in heroes_df['Publisher']]

# %% [markdown]
# Check your work below:

# %%
# Run this cell without changes
heroes_df["Publisher"].value_counts()
# Out:
# Marvel Comics        388
# DC Comics            215
# NBC - Heroes          19
# Dark Horse Comics     18
# Unknown               15
# Image Comics          14
# George Lucas          14
# Star Trek              6
# HarperCollins          6
# Team Epic TV           5
# SyFy                   5
# IDW Publishing         4
# Shueisha               4
# ABC Studios            4
# Icon Comics            4
# Wildstorm              3
# Sony Pictures          2
# J. R. R. Tolkien       1
# South Park             1
# Rebellion              1
# Hanna-Barbera          1
# Microsoft              1
# J. K. Rowling          1
# Titan Books            1
# Universal Studios      1
# Name: Publisher, dtype: int64

# %% [markdown]
# ### Answering the Question
#
# Now we should be able to answer *What is the distribution of superheroes by publisher?*
#
# If your data cleaning was done correctly, this code should work without any further changes:

# %%
# Run this cell without changes

# Set up plots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))

# Create variables for easier reuse
value_counts = heroes_df["Publisher"].value_counts()
top_5_counts = value_counts.iloc[:5]

# Plot data
ax1.bar(value_counts.index, value_counts.values)
ax2.bar(top_5_counts.index, top_5_counts.values)

# Customize appearance
ax1.tick_params(axis="x", labelrotation=90)
ax2.tick_params(axis="x", labelrotation=45)
ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Distribution of Superheroes by Publisher")
ax2.set_title("Top 5 Publishers by Count of Superheroes");

# %%
#After seeing this histogram, I realize having such a big category with 'unknown' publishers is not helpful in the
#analysis of the data. I will drop it to see who is the real fifth largest publisher, and also realizing in percentage
#we are not losing that much data by dropping it.

heroes_df.drop(heroes_df.loc[heroes_df['Publisher']=='Unknown'].index, inplace=True)

# %%
#And now repeating the same histograms
# Set up plots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(16, 5))

# Create variables for easier reuse
value_counts = heroes_df["Publisher"].value_counts()
top_5_counts = value_counts.iloc[:5]

# Plot data
ax1.bar(value_counts.index, value_counts.values)
ax2.bar(top_5_counts.index, top_5_counts.values)

# Customize appearance
ax1.tick_params(axis="x", labelrotation=90)
ax2.tick_params(axis="x", labelrotation=45)
ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Distribution of Superheroes by Publisher")
ax2.set_title("Top 5 Publishers by Count of Superheroes");

# %% [markdown]
# ## 3. Perform Data Aggregation and Cleaning Required to Answer Second Question
#
# Recall that the second question is: *What is the relationship between height and number of superpowers? And does this differ based on gender?*
#
# Unlike the previous question, we won't be able to answer this with just `heroes_df`, since information about height is contained in `heroes_df`, while information about superpowers is contained in `powers_df`.
#
# ### Joining the Dataframes Together
#
# First, identify the shared key between `heroes_df` and `powers_df`. (Shared key meaning, the values you want to join on.) Let's look at them again:

# %%
# Run this cell without changes
heroes_df.head(20)
# Out:
#                  name  Gender Eye color               Race Hair color  Height  \
# 0              A-Bomb    Male    yellow              Human    No Hair   203.0
# 1          Abe Sapien    Male      blue      Icthyo Sapien    No Hair   191.0
# 2            Abin Sur    Male      blue            Ungaran    No Hair   185.0
# 3         Abomination    Male     green  Human / Radiation    No Hair   203.0
# 4             Abraxas    Male      blue      Cosmic Entity      Black   -99.0
# 5       Absorbing Man    Male      blue              Human    No Hair   193.0
# 6         Adam Monroe    Male      blue                  -      Blond   -99.0
# 7        Adam Strange    Male      blue              Human      Blond   185.0
# 8            Agent 13  Female      blue                  -      Blond   173.0
# 9           Agent Bob    Male     brown              Human      Brown   178.0
# 10         Agent Zero    Male         -                  -          -   191.0
# 11         Air-Walker    Male      blue                  -      White   188.0
# 12               Ajax    Male     brown             Cyborg      Black   193.0
# 13         Alan Scott    Male      blue                  -      Blond   180.0
# 14        Alex Mercer    Male         -              Human          -   -99.0
# 15       Alex Woolsly    Male         -                  -          -   -99.0
# 16  Alfred Pennyworth    Male      blue              Human      Black   178.0
# 17              Alien    Male         -    Xenomorph XX121    No Hair   244.0
# 18   Allan Quatermain    Male         -                  -          -   -99.0
# 19              Amazo    Male       red            Android          -   257.0
#
#             Publisher Skin color Alignment  Weight
# 0       Marvel Comics          -      good   441.0
# 1   Dark Horse Comics       blue      good    65.0
# 2           DC Comics        red      good    90.0
# 3       Marvel Comics          -       bad   441.0
# 4       Marvel Comics          -       bad   -99.0
# 5       Marvel Comics          -       bad   122.0
# 6        NBC - Heroes          -      good   -99.0
# 7           DC Comics          -      good    88.0
# 8       Marvel Comics          -      good    61.0
# 9       Marvel Comics          -      good    81.0
# 10      Marvel Comics          -      good   104.0
# 11      Marvel Comics          -       bad   108.0
# 12      Marvel Comics          -       bad    90.0
# 13          DC Comics          -      good    90.0
# 14          Wildstorm          -       bad   -99.0
# 15       NBC - Heroes          -      good   -99.0
# 16          DC Comics          -      good    72.0
# 17  Dark Horse Comics      black       bad   169.0
# 18          Wildstorm          -      good   -99.0
# 19          DC Comics          -       bad   173.0

# %%
# Run this cell without changes
powers_df
# Out:
#                        3-D Man  A-Bomb  Abe Sapien  Abin Sur  Abomination  \
# Agility                   True   False        True     False        False
# Accelerated Healing      False    True        True     False         True
# Lantern Power Ring       False   False       False      True        False
# Dimensional Awareness    False   False       False     False        False
# Cold Resistance          False   False        True     False        False
# Durability               False    True        True     False        False
# Stealth                  False   False       False     False        False
# Energy Absorption        False   False       False     False        False
# Flight                   False   False       False     False        False
# Danger Sense             False   False       False     False        False
# Underwater breathing     False   False        True     False        False
# Marksmanship             False   False        True     False        False
# Weapons Master           False   False        True     False        False
# Power Augmentation       False   False       False     False        False
# Animal Attributes        False   False       False     False        False
# Longevity                False    True        True     False        False
# Intelligence             False   False        True     False         True
# Super Strength            True    True        True     False         True
# Cryokinesis              False   False       False     False        False
# Telepathy                False   False        True     False        False
# Energy Armor             False   False       False     False        False
# Energy Blasts            False   False       False     False        False
# Duplication              False   False       False     False        False
# Size Changing            False   False       False     False        False
# Density Control          False   False       False     False        False
# Stamina                   True    True        True     False         True
# Astral Travel            False   False       False     False        False
# Audio Control            False   False       False     False        False
# Dexterity                False   False       False     False        False
# Omnitrix                 False   False       False     False        False
# ...                        ...     ...         ...       ...          ...
# Intuitive aptitude       False   False       False     False        False
# Vision - Microscopic     False   False       False     False        False
# Melting                  False   False       False     False        False
# Wind Control             False   False       False     False        False
# Super Breath             False   False       False     False         True
# Wallcrawling             False   False       False     False        False
# Vision - Night           False   False       False     False        False
# Vision - Infrared        False   False       False     False        False
# Grim Reaping             False   False       False     False        False
# Matter Absorption        False   False       False     False        False
# The Force                False   False       False     False        False
# Resurrection             False   False       False     False        False
# Terrakinesis             False   False       False     False        False
# Vision - Heat            False   False       False     False        False
# Vitakinesis              False   False       False     False        False
# Radar Sense              False   False       False     False        False
# Qwardian Power Ring      False   False       False     False        False
# Weather Control          False   False       False     False        False
# Vision - X-Ray           False   False       False     False        False
# Vision - Thermal         False   False       False     False        False
# Web Creation             False   False       False     False        False
# Reality Warping          False   False       False     False        False
# Odin Force               False   False       False     False        False
# Symbiote Costume         False   False       False     False        False
# Speed Force              False   False       False     False        False
# Phoenix Force            False   False       False     False        False
# Molecular Dissipation    False   False       False     False        False
# Vision - Cryo            False   False       False     False        False
# Omnipresent              False   False       False     False        False
# Omniscient               False   False       False     False        False
#
#                        Abraxas  Absorbing Man  Adam Monroe  Adam Strange  \
# Agility                  False          False        False         False
# Accelerated Healing      False          False         True         False
# Lantern Power Ring       False          False        False         False
# Dimensional Awareness     True          False        False         False
# Cold Resistance          False           True        False         False
# Durability               False           True        False          True
# Stealth                  False          False        False          True
# Energy Absorption        False           True        False         False
# Flight                    True          False        False          True
# Danger Sense             False          False        False         False
# Underwater breathing     False          False        False         False
# Marksmanship             False          False        False          True
# Weapons Master           False          False        False          True
# Power Augmentation       False          False        False         False
# Animal Attributes        False          False        False         False
# Longevity                False          False        False         False
# Intelligence              True          False        False          True
# Super Strength            True           True        False         False
# Cryokinesis              False          False        False         False
# Telepathy                False          False        False         False
# Energy Armor             False          False        False         False
# Energy Blasts            False          False        False         False
# Duplication              False          False        False         False
# Size Changing             True          False        False         False
# Density Control          False          False        False         False
# Stamina                  False          False        False         False
# Astral Travel            False          False        False         False
# Audio Control            False          False        False         False
# Dexterity                False          False        False         False
# Omnitrix                 False          False        False         False
# ...                        ...            ...          ...           ...
# Intuitive aptitude       False          False        False         False
# Vision - Microscopic     False          False        False         False
# Melting                  False          False        False         False
# Wind Control             False          False        False         False
# Super Breath             False          False        False         False
# Wallcrawling             False          False        False         False
# Vision - Night           False          False        False         False
# Vision - Infrared        False          False        False         False
# Grim Reaping             False          False        False         False
# Matter Absorption        False           True        False         False
# The Force                False          False        False         False
# Resurrection             False          False        False         False
# Terrakinesis             False          False        False         False
# Vision - Heat            False          False        False         False
# Vitakinesis              False          False        False         False
# Radar Sense              False          False        False         False
# Qwardian Power Ring      False          False        False         False
# Weather Control          False          False        False         False
# Vision - X-Ray           False          False        False         False
# Vision - Thermal         False          False        False         False
# Web Creation             False          False        False         False
# Reality Warping          False          False        False         False
# Odin Force               False          False        False         False
# Symbiote Costume         False          False        False         False
# Speed Force              False          False        False         False
# Phoenix Force            False          False        False         False
# Molecular Dissipation    False          False        False         False
# Vision - Cryo            False          False        False         False
# Omnipresent              False          False        False         False
# Omniscient               False          False        False         False
#
#                        Agent Bob  ...    Wonder Man  Wonder Woman   X-23  \
# Agility                    False  ...         False         False   True
# Accelerated Healing        False  ...         False          True   True
# Lantern Power Ring         False  ...         False         False  False
# Dimensional Awareness      False  ...         False         False  False
# Cold Resistance            False  ...         False         False  False
# Durability                 False  ...          True          True   True
# Stealth                     True  ...         False         False   True
# Energy Absorption          False  ...         False         False  False
# Flight                     False  ...          True          True  False
# Danger Sense               False  ...         False         False  False
# Underwater breathing       False  ...         False         False  False
# Marksmanship               False  ...         False          True   True
# Weapons Master             False  ...         False          True  False
# Power Augmentation         False  ...         False         False  False
# Animal Attributes          False  ...         False         False  False
# Longevity                  False  ...          True          True   True
# Intelligence               False  ...         False          True  False
# Super Strength             False  ...          True          True   True
# Cryokinesis                False  ...         False         False  False
# Telepathy                  False  ...         False          True  False
# Energy Armor               False  ...         False         False  False
# Energy Blasts              False  ...          True         False  False
# Duplication                False  ...         False         False  False
# Size Changing              False  ...          True         False  False
# Density Control            False  ...         False         False  False
# Stamina                    False  ...          True          True   True
# Astral Travel              False  ...         False         False  False
# Audio Control              False  ...         False         False  False
# Dexterity                  False  ...         False         False  False
# Omnitrix                   False  ...         False         False  False
# ...                          ...  ...           ...           ...    ...
# Intuitive aptitude         False  ...         False         False  False
# Vision - Microscopic       False  ...         False          True  False
# Melting                    False  ...         False         False  False
# Wind Control               False  ...         False         False  False
# Super Breath               False  ...         False         False  False
# Wallcrawling               False  ...         False         False  False
# Vision - Night             False  ...         False          True   True
# Vision - Infrared          False  ...         False          True  False
# Grim Reaping               False  ...         False         False  False
# Matter Absorption          False  ...         False         False  False
# The Force                  False  ...         False         False  False
# Resurrection               False  ...         False         False  False
# Terrakinesis               False  ...         False         False  False
# Vision - Heat              False  ...         False         False  False
# Vitakinesis                False  ...         False         False  False
# Radar Sense                False  ...         False         False  False
# Qwardian Power Ring        False  ...         False         False  False
# Weather Control            False  ...         False         False  False
# Vision - X-Ray             False  ...         False          True  False
# Vision - Thermal           False  ...         False          True  False
# Web Creation               False  ...         False         False  False
# Reality Warping            False  ...         False         False  False
# Odin Force                 False  ...         False         False  False
# Symbiote Costume           False  ...         False         False  False
# Speed Force                False  ...         False         False  False
# Phoenix Force              False  ...         False         False  False
# Molecular Dissipation      False  ...         False         False  False
# Vision - Cryo              False  ...         False         False  False
# Omnipresent                False  ...         False         False  False
# Omniscient                 False  ...         False         False  False
#
#                        X-Man  Yellowjacket  Yellowjacket II   Ymir   Yoda  \
# Agility                False         False            False  False   True
# Accelerated Healing    False         False            False  False  False
# Lantern Power Ring     False         False            False  False  False
# Dimensional Awareness  False         False            False  False  False
# Cold Resistance        False         False            False   True  False
# Durability             False         False            False   True  False
# Stealth                False         False            False  False   True
# Energy Absorption      False         False            False  False  False
# Flight                  True         False             True  False  False
# Danger Sense           False         False            False  False   True
# Underwater breathing   False         False            False  False  False
# Marksmanship           False         False            False  False   True
# Weapons Master         False         False            False  False   True
# Power Augmentation     False         False            False  False  False
# Animal Attributes      False         False            False  False  False
# Longevity              False         False            False   True   True
# Intelligence           False         False            False  False   True
# Super Strength         False         False            False   True  False
# Cryokinesis            False         False            False   True  False
# Telepathy               True         False            False  False   True
# Energy Armor           False         False            False  False  False
# Energy Blasts          False         False             True  False   True
# Duplication            False         False            False  False  False
# Size Changing          False          True             True  False  False
# Density Control        False         False            False  False  False
# Stamina                False         False            False  False   True
# Astral Travel           True         False            False  False  False
# Audio Control          False         False            False  False  False
# Dexterity              False         False            False  False  False
# Omnitrix               False         False            False  False  False
# ...                      ...           ...              ...    ...    ...
# Intuitive aptitude     False         False            False  False  False
# Vision - Microscopic   False         False            False  False  False
# Melting                False         False            False  False  False
# Wind Control           False         False            False  False  False
# Super Breath           False         False            False  False  False
# Wallcrawling           False         False            False  False  False
# Vision - Night         False         False            False  False  False
# Vision - Infrared      False         False            False  False  False
# Grim Reaping           False         False            False  False  False
# Matter Absorption      False         False            False  False  False
# The Force              False         False            False  False   True
# Resurrection           False         False            False  False  False
# Terrakinesis           False         False            False  False  False
# Vision - Heat          False         False            False  False  False
# Vitakinesis            False         False            False  False  False
# Radar Sense            False         False            False  False  False
# Qwardian Power Ring    False         False            False  False  False
# Weather Control        False         False            False  False  False
# Vision - X-Ray         False         False            False  False  False
# Vision - Thermal       False         False            False  False  False
# Web Creation           False         False            False  False  False
# Reality Warping        False         False            False  False  False
# Odin Force             False         False            False  False  False
# Symbiote Costume       False         False            False  False  False
# Speed Force            False         False            False  False  False
# Phoenix Force          False         False            False  False  False
# Molecular Dissipation  False         False            False  False  False
# Vision - Cryo          False         False            False  False  False
# Omnipresent            False         False            False  False  False
# Omniscient             False         False            False  False  False
#
#                        Zatanna   Zoom
# Agility                  False  False
# Accelerated Healing      False  False
# Lantern Power Ring       False  False
# Dimensional Awareness    False  False
# Cold Resistance          False  False
# Durability               False  False
# Stealth                  False  False
# Energy Absorption        False  False
# Flight                   False  False
# Danger Sense             False  False
# Underwater breathing     False  False
# Marksmanship             False  False
# Weapons Master           False  False
# Power Augmentation       False  False
# Animal Attributes        False  False
# Longevity                False  False
# Intelligence             False  False
# Super Strength           False  False
# Cryokinesis               True  False
# Telepathy                 True  False
# Energy Armor             False  False
# Energy Blasts            False  False
# Duplication              False  False
# Size Changing            False  False
# Density Control          False  False
# Stamina                  False  False
# Astral Travel            False  False
# Audio Control            False  False
# Dexterity                False  False
# Omnitrix                 False  False
# ...                        ...    ...
# Intuitive aptitude       False  False
# Vision - Microscopic     False  False
# Melting                  False  False
# Wind Control             False  False
# Super Breath             False  False
# Wallcrawling             False  False
# Vision - Night           False  False
# Vision - Infrared        False  False
# Grim Reaping             False  False
# Matter Absorption        False  False
# The Force                False  False
# Resurrection             False  False
# Terrakinesis              True  False
# Vision - Heat            False  False
# Vitakinesis              False  False
# Radar Sense              False  False
# Qwardian Power Ring      False  False
# Weather Control           True  False
# Vision - X-Ray           False  False
# Vision - Thermal         False  False
# Web Creation             False  False
# Reality Warping          False  False
# Odin Force               False  False
# Symbiote Costume         False  False
# Speed Force              False  False
# Phoenix Force            False  False
# Molecular Dissipation    False  False
# Vision - Cryo            False  False
# Omnipresent              False  False
# Omniscient               False  False
#
# [167 rows x 667 columns]

# %% [markdown]
# In the cell below, identify the shared key, and your strategy for joining the data (e.g. what will one record represent after you join, will you do a left/right/inner/outer join):

# %%
# Replace None with appropriate text
"""
The shared key is the name of the super heroes.
The problem is that that is a column in the superheroes_df data frame and it is the index for the super powers 
data frame, I have to figure out how to merge/join them.
"""
# Out:
# '\nThe shared key is the name of the super heroes.\nThe problem is that that is a column in the superheroes_df data frame and it is the index for the super powers \ndata frame, I have to figure out how to merge/join them.\n'

# %% [markdown]
# In the cell below, create a new dataframe called `heroes_and_powers_df` that contains the joined data. You can look at the above answer in the solution branch if you're not sure where to start.
#
# ***Hint:*** Note that the `.join` method requires that the two dataframes share an index ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.join.html)) whereas the `.merge` method can join using any columns ([documentation here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.merge.html)). It is up to you which one you want to use.

# %%
powers_dftr=powers_df.transpose()
powers_dftr.head()
# Out:
#              Agility  Accelerated Healing  Lantern Power Ring  \
# 3-D Man         True                False               False
# A-Bomb         False                 True               False
# Abe Sapien      True                 True               False
# Abin Sur       False                False                True
# Abomination    False                 True               False
#
#              Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 3-D Man                      False            False       False    False
# A-Bomb                       False            False        True    False
# Abe Sapien                   False             True        True    False
# Abin Sur                     False            False       False    False
# Abomination                  False            False       False    False
#
#              Energy Absorption  Flight  Danger Sense     ...      \
# 3-D Man                  False   False         False     ...
# A-Bomb                   False   False         False     ...
# Abe Sapien               False   False         False     ...
# Abin Sur                 False   False         False     ...
# Abomination              False   False         False     ...
#
#              Web Creation  Reality Warping  Odin Force  Symbiote Costume  \
# 3-D Man             False            False       False             False
# A-Bomb              False            False       False             False
# Abe Sapien          False            False       False             False
# Abin Sur            False            False       False             False
# Abomination         False            False       False             False
#
#              Speed Force  Phoenix Force  Molecular Dissipation  Vision - Cryo  \
# 3-D Man            False          False                  False          False
# A-Bomb             False          False                  False          False
# Abe Sapien         False          False                  False          False
# Abin Sur           False          False                  False          False
# Abomination        False          False                  False          False
#
#              Omnipresent  Omniscient
# 3-D Man            False       False
# A-Bomb             False       False
# Abe Sapien         False       False
# Abin Sur           False       False
# Abomination        False       False
#
# [5 rows x 167 columns]

# %%
heroes_and_powers_df = heroes_df.merge(powers_dftr, left_on='name', right_index=True, how='inner')
heroes_and_powers_df
# Out:
#                  name  Gender Eye color               Race        Hair color  \
# 0              A-Bomb    Male    yellow              Human           No Hair
# 1          Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2            Abin Sur    Male      blue            Ungaran           No Hair
# 3         Abomination    Male     green  Human / Radiation           No Hair
# 4             Abraxas    Male      blue      Cosmic Entity             Black
# 5       Absorbing Man    Male      blue              Human           No Hair
# 6         Adam Monroe    Male      blue                  -             Blond
# 7        Adam Strange    Male      blue              Human             Blond
# 9           Agent Bob    Male     brown              Human             Brown
# 10         Agent Zero    Male         -                  -                 -
# 11         Air-Walker    Male      blue                  -             White
# 12               Ajax    Male     brown             Cyborg             Black
# 13         Alan Scott    Male      blue                  -             Blond
# 14        Alex Mercer    Male         -              Human                 -
# 15       Alex Woolsly    Male         -                  -                 -
# 17              Alien    Male         -    Xenomorph XX121           No Hair
# 18   Allan Quatermain    Male         -                  -                 -
# 19              Amazo    Male       red            Android                 -
# 20               Ammo    Male     brown              Human             Black
# 21     Ando Masahashi    Male         -                  -                 -
# 22              Angel    Male      blue                  -             Blond
# 23              Angel    Male         -            Vampire                 -
# 24         Angel Dust  Female    yellow             Mutant             Black
# 25    Angel Salvadore  Female     brown                  -             Black
# 26             Angela  Female         -                  -                 -
# 27         Animal Man    Male      blue              Human             Blond
# 28          Annihilus    Male     green                  -           No Hair
# 29            Ant-Man    Male      blue              Human             Blond
# 30         Ant-Man II    Male      blue              Human             Blond
# 31       Anti-Monitor    Male    yellow      God / Eternal           No Hair
# ..                ...     ...       ...                ...               ...
# 696        Vindicator    Male         -                  -                 -
# 697          Violator    Male         -                  -                 -
# 698       Violet Parr  Female    violet              Human             Black
# 699            Vision    Male      gold            Android           No Hair
# 701             Vixen  Female     amber              Human             Black
# 703           Vulture    Male     brown              Human           No Hair
# 704            Walrus    Male      blue              Human             Black
# 705       War Machine    Male     brown              Human             Brown
# 707           Warlock    Male       red                  -             Blond
# 708              Warp    Male     brown                  -             Black
# 709           Warpath    Male     brown             Mutant             Black
# 710              Wasp  Female      blue              Human            Auburn
# 711           Watcher    Male         -                  -                 -
# 712         Weapon XI    Male         -                  -                 -
# 713      White Canary  Female     brown              Human             Black
# 715          Wildfire    Male         -                  -                 -
# 716    Winter Soldier    Male     brown              Human             Brown
# 718         Wolfsbane  Female     green                  -            Auburn
# 719         Wolverine    Male      blue             Mutant             Black
# 720       Wonder Girl  Female      blue           Demi-God             Blond
# 721        Wonder Man    Male       red                  -             Black
# 722      Wonder Woman  Female      blue             Amazon             Black
# 725              X-23  Female     green     Mutant / Clone             Black
# 726             X-Man    Male      blue                  -             Brown
# 728      Yellowjacket    Male      blue              Human             Blond
# 729   Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730              Ymir    Male     white        Frost Giant           No Hair
# 731              Yoda    Male     brown     Yoda's species             White
# 732           Zatanna  Female      blue              Human             Black
# 733              Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight     ...      \
# 0     203.0      Marvel Comics          -      good   441.0     ...
# 1     191.0  Dark Horse Comics       blue      good    65.0     ...
# 2     185.0          DC Comics        red      good    90.0     ...
# 3     203.0      Marvel Comics          -       bad   441.0     ...
# 4     -99.0      Marvel Comics          -       bad   -99.0     ...
# 5     193.0      Marvel Comics          -       bad   122.0     ...
# 6     -99.0       NBC - Heroes          -      good   -99.0     ...
# 7     185.0          DC Comics          -      good    88.0     ...
# 9     178.0      Marvel Comics          -      good    81.0     ...
# 10    191.0      Marvel Comics          -      good   104.0     ...
# 11    188.0      Marvel Comics          -       bad   108.0     ...
# 12    193.0      Marvel Comics          -       bad    90.0     ...
# 13    180.0          DC Comics          -      good    90.0     ...
# 14    -99.0          Wildstorm          -       bad   -99.0     ...
# 15    -99.0       NBC - Heroes          -      good   -99.0     ...
# 17    244.0  Dark Horse Comics      black       bad   169.0     ...
# 18    -99.0          Wildstorm          -      good   -99.0     ...
# 19    257.0          DC Comics          -       bad   173.0     ...
# 20    188.0      Marvel Comics          -       bad   101.0     ...
# 21    -99.0       NBC - Heroes          -      good   -99.0     ...
# 22    183.0      Marvel Comics          -      good    68.0     ...
# 23    -99.0  Dark Horse Comics          -      good   -99.0     ...
# 24    165.0      Marvel Comics          -      good    57.0     ...
# 25    163.0      Marvel Comics          -      good    54.0     ...
# 26    -99.0       Image Comics          -       bad   -99.0     ...
# 27    183.0          DC Comics          -      good    83.0     ...
# 28    180.0      Marvel Comics          -       bad    90.0     ...
# 29    211.0      Marvel Comics          -      good   122.0     ...
# 30    183.0      Marvel Comics          -      good    86.0     ...
# 31     61.0          DC Comics          -       bad   -99.0     ...
# ..      ...                ...        ...       ...     ...     ...
# 696   -99.0      Marvel Comics          -      good   -99.0     ...
# 697   -99.0       Image Comics          -       bad   -99.0     ...
# 698   137.0  Dark Horse Comics          -      good    41.0     ...
# 699   191.0      Marvel Comics        red      good   135.0     ...
# 701   175.0          DC Comics          -      good    63.0     ...
# 703   180.0      Marvel Comics          -       bad    79.0     ...
# 704   183.0      Marvel Comics          -       bad   162.0     ...
# 705   185.0      Marvel Comics          -      good    95.0     ...
# 707   188.0      Marvel Comics          -      good   108.0     ...
# 708   173.0          DC Comics          -       bad    67.0     ...
# 709   218.0      Marvel Comics          -      good   158.0     ...
# 710   163.0      Marvel Comics          -      good    50.0     ...
# 711   -99.0      Marvel Comics          -      good   -99.0     ...
# 712   -99.0      Marvel Comics          -       bad   -99.0     ...
# 713   -99.0          DC Comics          -       bad   -99.0     ...
# 715   -99.0          DC Comics          -      good   -99.0     ...
# 716   175.0      Marvel Comics          -      good   117.0     ...
# 718   366.0      Marvel Comics          -      good   473.0     ...
# 719   160.0      Marvel Comics          -      good   135.0     ...
# 720   165.0          DC Comics          -      good    51.0     ...
# 721   188.0      Marvel Comics          -      good   171.0     ...
# 722   183.0          DC Comics          -      good    74.0     ...
# 725   155.0      Marvel Comics          -      good    50.0     ...
# 726   175.0      Marvel Comics          -      good    61.0     ...
# 728   183.0      Marvel Comics          -      good    83.0     ...
# 729   165.0      Marvel Comics          -      good    52.0     ...
# 730   304.8      Marvel Comics      white      good   -99.0     ...
# 731    66.0       George Lucas      green      good    17.0     ...
# 732   170.0          DC Comics          -      good    57.0     ...
# 733   185.0          DC Comics          -       bad    81.0     ...
#
#      Web Creation  Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0           False            False       False             False        False
# 1           False            False       False             False        False
# 2           False            False       False             False        False
# 3           False            False       False             False        False
# 4           False            False       False             False        False
# 5           False            False       False             False        False
# 6           False            False       False             False        False
# 7           False            False       False             False        False
# 9           False            False       False             False        False
# 10          False            False       False             False        False
# 11          False            False       False             False        False
# 12          False            False       False             False        False
# 13          False            False       False             False        False
# 14          False            False       False             False        False
# 15          False            False       False             False        False
# 17          False            False       False             False        False
# 18          False            False       False             False        False
# 19          False            False       False             False        False
# 20          False            False       False             False        False
# 21          False            False       False             False        False
# 22          False            False       False             False        False
# 23          False            False       False             False        False
# 24          False            False       False             False        False
# 25          False            False       False             False        False
# 26          False            False       False             False        False
# 27          False            False       False             False        False
# 28          False            False       False             False        False
# 29          False            False       False             False        False
# 30          False            False       False             False        False
# 31          False             True       False             False        False
# ..            ...              ...         ...               ...          ...
# 696         False            False       False             False        False
# 697         False            False       False             False        False
# 698         False            False       False             False        False
# 699         False            False       False             False        False
# 701         False            False       False             False        False
# 703         False            False       False             False        False
# 704         False            False       False             False        False
# 705         False            False       False             False        False
# 707         False            False       False             False        False
# 708         False            False       False             False        False
# 709         False            False       False             False        False
# 710         False            False       False             False        False
# 711         False            False       False             False        False
# 712         False            False       False             False        False
# 713         False            False       False             False        False
# 715         False            False       False             False        False
# 716         False            False       False             False        False
# 718         False            False       False             False        False
# 719         False            False       False             False        False
# 720         False            False       False             False        False
# 721         False            False       False             False        False
# 722         False            False       False             False        False
# 725         False            False       False             False        False
# 726         False            False       False             False        False
# 728         False            False       False             False        False
# 729         False            False       False             False        False
# 730         False            False       False             False        False
# 731         False            False       False             False        False
# 732         False            False       False             False        False
# 733         False            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# 5            False                  False          False        False
# 6            False                  False          False        False
# 7            False                  False          False        False
# 9            False                  False          False        False
# 10           False                  False          False        False
# 11           False                  False          False        False
# 12           False                  False          False        False
# 13           False                  False          False        False
# 14           False                  False          False        False
# 15           False                  False          False        False
# 17           False                  False          False        False
# 18           False                  False          False        False
# 19           False                  False          False        False
# 20           False                  False          False        False
# 21           False                  False          False        False
# 22           False                  False          False        False
# 23           False                  False          False        False
# 24           False                  False          False        False
# 25           False                  False          False        False
# 26           False                  False          False        False
# 27           False                  False          False        False
# 28           False                  False          False        False
# 29           False                  False          False        False
# 30           False                  False          False        False
# 31           False                  False          False        False
# ..             ...                    ...            ...          ...
# 696          False                  False          False        False
# 697          False                  False          False        False
# 698          False                  False          False        False
# 699          False                  False          False        False
# 701          False                  False          False        False
# 703          False                  False          False        False
# 704          False                  False          False        False
# 705          False                  False          False        False
# 707          False                  False          False        False
# 708          False                  False          False        False
# 709          False                  False          False        False
# 710          False                  False          False        False
# 711          False                  False          False        False
# 712          False                  False          False        False
# 713          False                  False          False        False
# 715          False                  False          False        False
# 716          False                  False          False        False
# 718          False                  False          False        False
# 719          False                  False          False        False
# 720          False                  False          False        False
# 721          False                  False          False        False
# 722          False                  False          False        False
# 725          False                  False          False        False
# 726          False                  False          False        False
# 728          False                  False          False        False
# 729          False                  False          False        False
# 730          False                  False          False        False
# 731          False                  False          False        False
# 732          False                  False          False        False
# 733          False                  False          False        False
#
#      Omniscient
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
# 5         False
# 6         False
# 7         False
# 9         False
# 10        False
# 11        False
# 12        False
# 13        False
# 14        False
# 15        False
# 17        False
# 18        False
# 19        False
# 20        False
# 21        False
# 22        False
# 23        False
# 24        False
# 25        False
# 26        False
# 27        False
# 28        False
# 29        False
# 30        False
# 31        False
# ..          ...
# 696       False
# 697       False
# 698       False
# 699       False
# 701       False
# 703       False
# 704       False
# 705       False
# 707       False
# 708       False
# 709       False
# 710       False
# 711       False
# 712       False
# 713       False
# 715       False
# 716       False
# 718       False
# 719       False
# 720       False
# 721       False
# 722       False
# 725       False
# 726       False
# 728       False
# 729       False
# 730       False
# 731       False
# 732       False
# 733       False
#
# [647 rows x 177 columns]

# %% [markdown]
# Run the code below to check your work:

# %%
# Run this cell without changes

# Confirms you have created a dataframe with the specified name
assert type(heroes_and_powers_df) == pd.DataFrame

# Confirms you have the right number of rows
assert heroes_and_powers_df.shape[0] == 647

# Confirms you have the necessary columns
# (If you modified the value of powers_df along the way, you might need to
# modify this test. We are checking that all of the powers are present as
# columns.)
assert [power in heroes_and_powers_df.columns for power in powers_df.index]
# (If you modified the value of heroes_df along the way, you mgith need to 
# modify this as well. We are checking that all of the attribute columns from
# heroes_df are present as columns in the joined df)
assert [attribute in heroes_and_powers_df.columns for attribute in heroes_df.columns]

# %% [markdown]
# Now that we have created a joined dataframe, we can aggregate the number of superpowers by superhero. This code is written for you:

# %%
# Run this cell without changes

# Note: we can use sum() with True and False values and they will
# automatically be cast to 1s and 0s
heroes_and_powers_df["Power Count"] = sum([heroes_and_powers_df[power_name] for power_name in powers_df.index])
heroes_and_powers_df
# Out:
#                  name  Gender Eye color               Race        Hair color  \
# 0              A-Bomb    Male    yellow              Human           No Hair
# 1          Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2            Abin Sur    Male      blue            Ungaran           No Hair
# 3         Abomination    Male     green  Human / Radiation           No Hair
# 4             Abraxas    Male      blue      Cosmic Entity             Black
# 5       Absorbing Man    Male      blue              Human           No Hair
# 6         Adam Monroe    Male      blue                  -             Blond
# 7        Adam Strange    Male      blue              Human             Blond
# 9           Agent Bob    Male     brown              Human             Brown
# 10         Agent Zero    Male         -                  -                 -
# 11         Air-Walker    Male      blue                  -             White
# 12               Ajax    Male     brown             Cyborg             Black
# 13         Alan Scott    Male      blue                  -             Blond
# 14        Alex Mercer    Male         -              Human                 -
# 15       Alex Woolsly    Male         -                  -                 -
# 17              Alien    Male         -    Xenomorph XX121           No Hair
# 18   Allan Quatermain    Male         -                  -                 -
# 19              Amazo    Male       red            Android                 -
# 20               Ammo    Male     brown              Human             Black
# 21     Ando Masahashi    Male         -                  -                 -
# 22              Angel    Male      blue                  -             Blond
# 23              Angel    Male         -            Vampire                 -
# 24         Angel Dust  Female    yellow             Mutant             Black
# 25    Angel Salvadore  Female     brown                  -             Black
# 26             Angela  Female         -                  -                 -
# 27         Animal Man    Male      blue              Human             Blond
# 28          Annihilus    Male     green                  -           No Hair
# 29            Ant-Man    Male      blue              Human             Blond
# 30         Ant-Man II    Male      blue              Human             Blond
# 31       Anti-Monitor    Male    yellow      God / Eternal           No Hair
# ..                ...     ...       ...                ...               ...
# 696        Vindicator    Male         -                  -                 -
# 697          Violator    Male         -                  -                 -
# 698       Violet Parr  Female    violet              Human             Black
# 699            Vision    Male      gold            Android           No Hair
# 701             Vixen  Female     amber              Human             Black
# 703           Vulture    Male     brown              Human           No Hair
# 704            Walrus    Male      blue              Human             Black
# 705       War Machine    Male     brown              Human             Brown
# 707           Warlock    Male       red                  -             Blond
# 708              Warp    Male     brown                  -             Black
# 709           Warpath    Male     brown             Mutant             Black
# 710              Wasp  Female      blue              Human            Auburn
# 711           Watcher    Male         -                  -                 -
# 712         Weapon XI    Male         -                  -                 -
# 713      White Canary  Female     brown              Human             Black
# 715          Wildfire    Male         -                  -                 -
# 716    Winter Soldier    Male     brown              Human             Brown
# 718         Wolfsbane  Female     green                  -            Auburn
# 719         Wolverine    Male      blue             Mutant             Black
# 720       Wonder Girl  Female      blue           Demi-God             Blond
# 721        Wonder Man    Male       red                  -             Black
# 722      Wonder Woman  Female      blue             Amazon             Black
# 725              X-23  Female     green     Mutant / Clone             Black
# 726             X-Man    Male      blue                  -             Brown
# 728      Yellowjacket    Male      blue              Human             Blond
# 729   Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730              Ymir    Male     white        Frost Giant           No Hair
# 731              Yoda    Male     brown     Yoda's species             White
# 732           Zatanna  Female      blue              Human             Black
# 733              Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight     ...       \
# 0     203.0      Marvel Comics          -      good   441.0     ...
# 1     191.0  Dark Horse Comics       blue      good    65.0     ...
# 2     185.0          DC Comics        red      good    90.0     ...
# 3     203.0      Marvel Comics          -       bad   441.0     ...
# 4     -99.0      Marvel Comics          -       bad   -99.0     ...
# 5     193.0      Marvel Comics          -       bad   122.0     ...
# 6     -99.0       NBC - Heroes          -      good   -99.0     ...
# 7     185.0          DC Comics          -      good    88.0     ...
# 9     178.0      Marvel Comics          -      good    81.0     ...
# 10    191.0      Marvel Comics          -      good   104.0     ...
# 11    188.0      Marvel Comics          -       bad   108.0     ...
# 12    193.0      Marvel Comics          -       bad    90.0     ...
# 13    180.0          DC Comics          -      good    90.0     ...
# 14    -99.0          Wildstorm          -       bad   -99.0     ...
# 15    -99.0       NBC - Heroes          -      good   -99.0     ...
# 17    244.0  Dark Horse Comics      black       bad   169.0     ...
# 18    -99.0          Wildstorm          -      good   -99.0     ...
# 19    257.0          DC Comics          -       bad   173.0     ...
# 20    188.0      Marvel Comics          -       bad   101.0     ...
# 21    -99.0       NBC - Heroes          -      good   -99.0     ...
# 22    183.0      Marvel Comics          -      good    68.0     ...
# 23    -99.0  Dark Horse Comics          -      good   -99.0     ...
# 24    165.0      Marvel Comics          -      good    57.0     ...
# 25    163.0      Marvel Comics          -      good    54.0     ...
# 26    -99.0       Image Comics          -       bad   -99.0     ...
# 27    183.0          DC Comics          -      good    83.0     ...
# 28    180.0      Marvel Comics          -       bad    90.0     ...
# 29    211.0      Marvel Comics          -      good   122.0     ...
# 30    183.0      Marvel Comics          -      good    86.0     ...
# 31     61.0          DC Comics          -       bad   -99.0     ...
# ..      ...                ...        ...       ...     ...     ...
# 696   -99.0      Marvel Comics          -      good   -99.0     ...
# 697   -99.0       Image Comics          -       bad   -99.0     ...
# 698   137.0  Dark Horse Comics          -      good    41.0     ...
# 699   191.0      Marvel Comics        red      good   135.0     ...
# 701   175.0          DC Comics          -      good    63.0     ...
# 703   180.0      Marvel Comics          -       bad    79.0     ...
# 704   183.0      Marvel Comics          -       bad   162.0     ...
# 705   185.0      Marvel Comics          -      good    95.0     ...
# 707   188.0      Marvel Comics          -      good   108.0     ...
# 708   173.0          DC Comics          -       bad    67.0     ...
# 709   218.0      Marvel Comics          -      good   158.0     ...
# 710   163.0      Marvel Comics          -      good    50.0     ...
# 711   -99.0      Marvel Comics          -      good   -99.0     ...
# 712   -99.0      Marvel Comics          -       bad   -99.0     ...
# 713   -99.0          DC Comics          -       bad   -99.0     ...
# 715   -99.0          DC Comics          -      good   -99.0     ...
# 716   175.0      Marvel Comics          -      good   117.0     ...
# 718   366.0      Marvel Comics          -      good   473.0     ...
# 719   160.0      Marvel Comics          -      good   135.0     ...
# 720   165.0          DC Comics          -      good    51.0     ...
# 721   188.0      Marvel Comics          -      good   171.0     ...
# 722   183.0          DC Comics          -      good    74.0     ...
# 725   155.0      Marvel Comics          -      good    50.0     ...
# 726   175.0      Marvel Comics          -      good    61.0     ...
# 728   183.0      Marvel Comics          -      good    83.0     ...
# 729   165.0      Marvel Comics          -      good    52.0     ...
# 730   304.8      Marvel Comics      white      good   -99.0     ...
# 731    66.0       George Lucas      green      good    17.0     ...
# 732   170.0          DC Comics          -      good    57.0     ...
# 733   185.0          DC Comics          -       bad    81.0     ...
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 4              False       False             False        False
# 5              False       False             False        False
# 6              False       False             False        False
# 7              False       False             False        False
# 9              False       False             False        False
# 10             False       False             False        False
# 11             False       False             False        False
# 12             False       False             False        False
# 13             False       False             False        False
# 14             False       False             False        False
# 15             False       False             False        False
# 17             False       False             False        False
# 18             False       False             False        False
# 19             False       False             False        False
# 20             False       False             False        False
# 21             False       False             False        False
# 22             False       False             False        False
# 23             False       False             False        False
# 24             False       False             False        False
# 25             False       False             False        False
# 26             False       False             False        False
# 27             False       False             False        False
# 28             False       False             False        False
# 29             False       False             False        False
# 30             False       False             False        False
# 31              True       False             False        False
# ..               ...         ...               ...          ...
# 696            False       False             False        False
# 697            False       False             False        False
# 698            False       False             False        False
# 699            False       False             False        False
# 701            False       False             False        False
# 703            False       False             False        False
# 704            False       False             False        False
# 705            False       False             False        False
# 707            False       False             False        False
# 708            False       False             False        False
# 709            False       False             False        False
# 710            False       False             False        False
# 711            False       False             False        False
# 712            False       False             False        False
# 713            False       False             False        False
# 715            False       False             False        False
# 716            False       False             False        False
# 718            False       False             False        False
# 719            False       False             False        False
# 720            False       False             False        False
# 721            False       False             False        False
# 722            False       False             False        False
# 725            False       False             False        False
# 726            False       False             False        False
# 728            False       False             False        False
# 729            False       False             False        False
# 730            False       False             False        False
# 731            False       False             False        False
# 732            False       False             False        False
# 733            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 4            False                  False          False        False
# 5            False                  False          False        False
# 6            False                  False          False        False
# 7            False                  False          False        False
# 9            False                  False          False        False
# 10           False                  False          False        False
# 11           False                  False          False        False
# 12           False                  False          False        False
# 13           False                  False          False        False
# 14           False                  False          False        False
# 15           False                  False          False        False
# 17           False                  False          False        False
# 18           False                  False          False        False
# 19           False                  False          False        False
# 20           False                  False          False        False
# 21           False                  False          False        False
# 22           False                  False          False        False
# 23           False                  False          False        False
# 24           False                  False          False        False
# 25           False                  False          False        False
# 26           False                  False          False        False
# 27           False                  False          False        False
# 28           False                  False          False        False
# 29           False                  False          False        False
# 30           False                  False          False        False
# 31           False                  False          False        False
# ..             ...                    ...            ...          ...
# 696          False                  False          False        False
# 697          False                  False          False        False
# 698          False                  False          False        False
# 699          False                  False          False        False
# 701          False                  False          False        False
# 703          False                  False          False        False
# 704          False                  False          False        False
# 705          False                  False          False        False
# 707          False                  False          False        False
# 708          False                  False          False        False
# 709          False                  False          False        False
# 710          False                  False          False        False
# 711          False                  False          False        False
# 712          False                  False          False        False
# 713          False                  False          False        False
# 715          False                  False          False        False
# 716          False                  False          False        False
# 718          False                  False          False        False
# 719          False                  False          False        False
# 720          False                  False          False        False
# 721          False                  False          False        False
# 722          False                  False          False        False
# 725          False                  False          False        False
# 726          False                  False          False        False
# 728          False                  False          False        False
# 729          False                  False          False        False
# 730          False                  False          False        False
# 731          False                  False          False        False
# 732          False                  False          False        False
# 733          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 4         False           14
# 5         False           11
# 6         False            3
# 7         False           10
# 9         False            1
# 10        False            6
# 11        False            6
# 12        False            5
# 13        False           13
# 14        False           27
# 15        False            1
# 17        False           14
# 18        False            1
# 19        False           44
# 20        False            1
# 21        False            1
# 22        False           18
# 23        False           18
# 24        False            4
# 25        False            5
# 26        False            1
# 27        False            5
# 28        False            7
# 29        False            2
# 30        False            9
# 31        False           23
# ..          ...          ...
# 696       False            8
# 697       False            5
# 698       False            6
# 699       False           20
# 701       False           17
# 703       False            8
# 704       False            4
# 705       False           18
# 707       False            9
# 708       False            2
# 709       False           11
# 710       False            9
# 711       False           18
# 712       False            7
# 713       False            5
# 715       False            8
# 716       False            5
# 718       False            8
# 719       False           21
# 720       False            9
# 721       False           11
# 722       False           30
# 725       False           17
# 726       False           11
# 728       False            2
# 729       False            3
# 730       False            6
# 731       False           19
# 732       False            8
# 733       False            4
#
# [647 rows x 178 columns]

# %% [markdown]
# ### Answering the Question
#
# Now we can plot the height vs. the count of powers:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=heroes_and_powers_df["Height"],
    y=heroes_and_powers_df["Power Count"],
    alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Hmm...what is that stack of values off below zero? What is a "negative" height?

# %%
heroes_and_powers_df.loc[:,['name','Height']].max()# I was just curious about who was that tallest one around 1000
# Out:
# name      Zoom
# Height     975
# dtype: object

# %% [markdown]
# ### Identifying and Handling Invalid values
#
# One of the trickier tasks in data cleaning is identifying invalid or impossible values. In these cases, you have to apply your domain knowledge rather than any particular computational technique. For example, if you were looking at data containing dates of past home sales, and one of those dates was 100 years in the future, pandas wouldn't flag that as an issue, but you as a data scientist should be able to identify it.
#
# In this case, we are looking at heights, which are 1-dimensional, positive numbers. In theory we could have a very tiny height close to 0 cm because the hero is microscopic, but it does not make sense that we would have a height below zero.
#
# Let's take a look at a sample of those negative heights:

# %%
# Run this cell without changes
heroes_and_powers_df[heroes_and_powers_df["Height"] < 0].sample(5, random_state=1)
# Out:
#                  name  Gender Eye color   Race        Hair color  Height  \
# 169         Chameleon    Male         -      -                 -   -99.0
# 188  Crimson Crusader    Male      blue      -  Strawberry Blond   -99.0
# 419              Luna  Female         -  Human                 -   -99.0
# 364         JJ Powell    Male         -      -                 -   -99.0
# 712         Weapon XI    Male         -      -                 -   -99.0
#
#          Publisher Skin color Alignment  Weight     ...       Reality Warping  \
# 169      DC Comics          -       bad   -99.0     ...                 False
# 188  Marvel Comics          -      good   -99.0     ...                 False
# 419  Marvel Comics          -      good   -99.0     ...                 False
# 364    ABC Studios          -      good   -99.0     ...                 False
# 712  Marvel Comics          -       bad   -99.0     ...                 False
#
#      Odin Force  Symbiote Costume  Speed Force  Phoenix Force  \
# 169       False             False        False          False
# 188       False             False        False          False
# 419       False             False        False          False
# 364       False             False        False          False
# 712       False             False        False          False
#
#      Molecular Dissipation  Vision - Cryo  Omnipresent  Omniscient  \
# 169                  False          False        False       False
# 188                  False          False        False       False
# 419                  False          False        False       False
# 364                  False          False        False       False
# 712                  False          False        False       False
#
#      Power Count
# 169            1
# 188            4
# 419            1
# 364            1
# 712            7
#
# [5 rows x 178 columns]

# %% [markdown]
# It looks like not only are those heights negative, those weights are negative also, and all of them are set to exactly -99.0.
#
# It seems like this data source probably filled in -99.0 as the height or weight whenever it was unknown, instead of just leaving it as NaN.
#
# Depending on the purpose of the analysis, maybe this would be a useful piece of information, but for our current question, let's go ahead and drop the records where the height is -99.0. We'll make a new temporary dataframe to make sure we don't accidentally delete anything that will be needed in a future question.

# %%
# Run this cell without changes
question_2_df = heroes_and_powers_df[heroes_and_powers_df["Height"] != -99.0].copy()
question_2_df
# Out:
#                 name  Gender Eye color               Race        Hair color  \
# 0             A-Bomb    Male    yellow              Human           No Hair
# 1         Abe Sapien    Male      blue      Icthyo Sapien           No Hair
# 2           Abin Sur    Male      blue            Ungaran           No Hair
# 3        Abomination    Male     green  Human / Radiation           No Hair
# 5      Absorbing Man    Male      blue              Human           No Hair
# 7       Adam Strange    Male      blue              Human             Blond
# 9          Agent Bob    Male     brown              Human             Brown
# 10        Agent Zero    Male         -                  -                 -
# 11        Air-Walker    Male      blue                  -             White
# 12              Ajax    Male     brown             Cyborg             Black
# 13        Alan Scott    Male      blue                  -             Blond
# 17             Alien    Male         -    Xenomorph XX121           No Hair
# 19             Amazo    Male       red            Android                 -
# 20              Ammo    Male     brown              Human             Black
# 22             Angel    Male      blue                  -             Blond
# 24        Angel Dust  Female    yellow             Mutant             Black
# 25   Angel Salvadore  Female     brown                  -             Black
# 27        Animal Man    Male      blue              Human             Blond
# 28         Annihilus    Male     green                  -           No Hair
# 29           Ant-Man    Male      blue              Human             Blond
# 30        Ant-Man II    Male      blue              Human             Blond
# 31      Anti-Monitor    Male    yellow      God / Eternal           No Hair
# 33        Anti-Venom    Male      blue           Symbiote             Blond
# 34        Apocalypse    Male       red             Mutant             Black
# 36           Aqualad    Male      blue          Atlantean             Black
# 37           Aquaman    Male      blue          Atlantean             Blond
# 38           Arachne  Female      blue              Human             Blond
# 39         Archangel    Male      blue             Mutant             Blond
# 40          Arclight  Female    violet                  -            Purple
# 41            Ardina  Female     white              Alien            Orange
# ..               ...     ...       ...                ...               ...
# 690         Venom II    Male     brown                  -             Black
# 691        Venom III    Male     brown           Symbiote             Brown
# 692        Venompool    Male         -           Symbiote                 -
# 693       Vertigo II  Female      blue                  -            Silver
# 694             Vibe    Male     brown              Human             Black
# 695       Vindicator  Female     green              Human               Red
# 698      Violet Parr  Female    violet              Human             Black
# 699           Vision    Male      gold            Android           No Hair
# 701            Vixen  Female     amber              Human             Black
# 703          Vulture    Male     brown              Human           No Hair
# 704           Walrus    Male      blue              Human             Black
# 705      War Machine    Male     brown              Human             Brown
# 707          Warlock    Male       red                  -             Blond
# 708             Warp    Male     brown                  -             Black
# 709          Warpath    Male     brown             Mutant             Black
# 710             Wasp  Female      blue              Human            Auburn
# 716   Winter Soldier    Male     brown              Human             Brown
# 718        Wolfsbane  Female     green                  -            Auburn
# 719        Wolverine    Male      blue             Mutant             Black
# 720      Wonder Girl  Female      blue           Demi-God             Blond
# 721       Wonder Man    Male       red                  -             Black
# 722     Wonder Woman  Female      blue             Amazon             Black
# 725             X-23  Female     green     Mutant / Clone             Black
# 726            X-Man    Male      blue                  -             Brown
# 728     Yellowjacket    Male      blue              Human             Blond
# 729  Yellowjacket II  Female      blue              Human  Strawberry Blond
# 730             Ymir    Male     white        Frost Giant           No Hair
# 731             Yoda    Male     brown     Yoda's species             White
# 732          Zatanna  Female      blue              Human             Black
# 733             Zoom    Male       red                  -             Brown
#
#      Height          Publisher Skin color Alignment  Weight     ...       \
# 0     203.0      Marvel Comics          -      good   441.0     ...
# 1     191.0  Dark Horse Comics       blue      good    65.0     ...
# 2     185.0          DC Comics        red      good    90.0     ...
# 3     203.0      Marvel Comics          -       bad   441.0     ...
# 5     193.0      Marvel Comics          -       bad   122.0     ...
# 7     185.0          DC Comics          -      good    88.0     ...
# 9     178.0      Marvel Comics          -      good    81.0     ...
# 10    191.0      Marvel Comics          -      good   104.0     ...
# 11    188.0      Marvel Comics          -       bad   108.0     ...
# 12    193.0      Marvel Comics          -       bad    90.0     ...
# 13    180.0          DC Comics          -      good    90.0     ...
# 17    244.0  Dark Horse Comics      black       bad   169.0     ...
# 19    257.0          DC Comics          -       bad   173.0     ...
# 20    188.0      Marvel Comics          -       bad   101.0     ...
# 22    183.0      Marvel Comics          -      good    68.0     ...
# 24    165.0      Marvel Comics          -      good    57.0     ...
# 25    163.0      Marvel Comics          -      good    54.0     ...
# 27    183.0          DC Comics          -      good    83.0     ...
# 28    180.0      Marvel Comics          -       bad    90.0     ...
# 29    211.0      Marvel Comics          -      good   122.0     ...
# 30    183.0      Marvel Comics          -      good    86.0     ...
# 31     61.0          DC Comics          -       bad   -99.0     ...
# 33    229.0      Marvel Comics          -         -   358.0     ...
# 34    213.0      Marvel Comics       grey       bad   135.0     ...
# 36    178.0          DC Comics          -      good   106.0     ...
# 37    185.0          DC Comics          -      good   146.0     ...
# 38    175.0      Marvel Comics          -      good    63.0     ...
# 39    183.0      Marvel Comics       blue      good    68.0     ...
# 40    173.0      Marvel Comics          -       bad    57.0     ...
# 41    193.0      Marvel Comics       gold      good    98.0     ...
# ..      ...                ...        ...       ...     ...     ...
# 690   175.0      Marvel Comics          -       bad    50.0     ...
# 691   229.0      Marvel Comics          -       bad   334.0     ...
# 692   226.0      Marvel Comics          -         -   -99.0     ...
# 693   168.0      Marvel Comics          -      good    52.0     ...
# 694   178.0          DC Comics          -      good    71.0     ...
# 695   165.0      Marvel Comics          -      good    54.0     ...
# 698   137.0  Dark Horse Comics          -      good    41.0     ...
# 699   191.0      Marvel Comics        red      good   135.0     ...
# 701   175.0          DC Comics          -      good    63.0     ...
# 703   180.0      Marvel Comics          -       bad    79.0     ...
# 704   183.0      Marvel Comics          -       bad   162.0     ...
# 705   185.0      Marvel Comics          -      good    95.0     ...
# 707   188.0      Marvel Comics          -      good   108.0     ...
# 708   173.0          DC Comics          -       bad    67.0     ...
# 709   218.0      Marvel Comics          -      good   158.0     ...
# 710   163.0      Marvel Comics          -      good    50.0     ...
# 716   175.0      Marvel Comics          -      good   117.0     ...
# 718   366.0      Marvel Comics          -      good   473.0     ...
# 719   160.0      Marvel Comics          -      good   135.0     ...
# 720   165.0          DC Comics          -      good    51.0     ...
# 721   188.0      Marvel Comics          -      good   171.0     ...
# 722   183.0          DC Comics          -      good    74.0     ...
# 725   155.0      Marvel Comics          -      good    50.0     ...
# 726   175.0      Marvel Comics          -      good    61.0     ...
# 728   183.0      Marvel Comics          -      good    83.0     ...
# 729   165.0      Marvel Comics          -      good    52.0     ...
# 730   304.8      Marvel Comics      white      good   -99.0     ...
# 731    66.0       George Lucas      green      good    17.0     ...
# 732   170.0          DC Comics          -      good    57.0     ...
# 733   185.0          DC Comics          -       bad    81.0     ...
#
#      Reality Warping  Odin Force  Symbiote Costume  Speed Force  \
# 0              False       False             False        False
# 1              False       False             False        False
# 2              False       False             False        False
# 3              False       False             False        False
# 5              False       False             False        False
# 7              False       False             False        False
# 9              False       False             False        False
# 10             False       False             False        False
# 11             False       False             False        False
# 12             False       False             False        False
# 13             False       False             False        False
# 17             False       False             False        False
# 19             False       False             False        False
# 20             False       False             False        False
# 22             False       False             False        False
# 24             False       False             False        False
# 25             False       False             False        False
# 27             False       False             False        False
# 28             False       False             False        False
# 29             False       False             False        False
# 30             False       False             False        False
# 31              True       False             False        False
# 33             False       False              True        False
# 34             False       False             False        False
# 36             False       False             False        False
# 37             False       False             False        False
# 38             False       False             False        False
# 39             False       False             False        False
# 40             False       False             False        False
# 41             False       False             False        False
# ..               ...         ...               ...          ...
# 690            False       False             False        False
# 691            False       False              True        False
# 692            False       False              True        False
# 693            False       False             False        False
# 694            False       False             False        False
# 695            False       False             False        False
# 698            False       False             False        False
# 699            False       False             False        False
# 701            False       False             False        False
# 703            False       False             False        False
# 704            False       False             False        False
# 705            False       False             False        False
# 707            False       False             False        False
# 708            False       False             False        False
# 709            False       False             False        False
# 710            False       False             False        False
# 716            False       False             False        False
# 718            False       False             False        False
# 719            False       False             False        False
# 720            False       False             False        False
# 721            False       False             False        False
# 722            False       False             False        False
# 725            False       False             False        False
# 726            False       False             False        False
# 728            False       False             False        False
# 729            False       False             False        False
# 730            False       False             False        False
# 731            False       False             False        False
# 732            False       False             False        False
# 733            False       False             False        False
#
#      Phoenix Force  Molecular Dissipation  Vision - Cryo  Omnipresent  \
# 0            False                  False          False        False
# 1            False                  False          False        False
# 2            False                  False          False        False
# 3            False                  False          False        False
# 5            False                  False          False        False
# 7            False                  False          False        False
# 9            False                  False          False        False
# 10           False                  False          False        False
# 11           False                  False          False        False
# 12           False                  False          False        False
# 13           False                  False          False        False
# 17           False                  False          False        False
# 19           False                  False          False        False
# 20           False                  False          False        False
# 22           False                  False          False        False
# 24           False                  False          False        False
# 25           False                  False          False        False
# 27           False                  False          False        False
# 28           False                  False          False        False
# 29           False                  False          False        False
# 30           False                  False          False        False
# 31           False                  False          False        False
# 33           False                  False          False        False
# 34           False                  False          False        False
# 36           False                  False          False        False
# 37           False                  False          False        False
# 38           False                  False          False        False
# 39           False                  False          False        False
# 40           False                  False          False        False
# 41           False                  False          False        False
# ..             ...                    ...            ...          ...
# 690          False                  False          False        False
# 691          False                  False          False        False
# 692          False                  False          False        False
# 693          False                  False          False        False
# 694          False                  False          False        False
# 695          False                  False          False        False
# 698          False                  False          False        False
# 699          False                  False          False        False
# 701          False                  False          False        False
# 703          False                  False          False        False
# 704          False                  False          False        False
# 705          False                  False          False        False
# 707          False                  False          False        False
# 708          False                  False          False        False
# 709          False                  False          False        False
# 710          False                  False          False        False
# 716          False                  False          False        False
# 718          False                  False          False        False
# 719          False                  False          False        False
# 720          False                  False          False        False
# 721          False                  False          False        False
# 722          False                  False          False        False
# 725          False                  False          False        False
# 726          False                  False          False        False
# 728          False                  False          False        False
# 729          False                  False          False        False
# 730          False                  False          False        False
# 731          False                  False          False        False
# 732          False                  False          False        False
# 733          False                  False          False        False
#
#      Omniscient  Power Count
# 0         False            7
# 1         False           16
# 2         False            1
# 3         False            8
# 5         False           11
# 7         False           10
# 9         False            1
# 10        False            6
# 11        False            6
# 12        False            5
# 13        False           13
# 17        False           14
# 19        False           44
# 20        False            1
# 22        False           18
# 24        False            4
# 25        False            5
# 27        False            5
# 28        False            7
# 29        False            2
# 30        False            9
# 31        False           23
# 33        False           14
# 34        False           23
# 36        False           13
# 37        False           24
# 38        False           12
# 39        False            8
# 40        False            4
# 41        False           17
# ..          ...          ...
# 690       False            9
# 691       False           13
# 692       False           26
# 693       False            1
# 694       False            6
# 695       False            8
# 698       False            6
# 699       False           20
# 701       False           17
# 703       False            8
# 704       False            4
# 705       False           18
# 707       False            9
# 708       False            2
# 709       False           11
# 710       False            9
# 716       False            5
# 718       False            8
# 719       False           21
# 720       False            9
# 721       False           11
# 722       False           30
# 725       False           17
# 726       False           11
# 728       False            2
# 729       False            3
# 730       False            6
# 731       False           19
# 732       False            8
# 733       False            4
#
# [484 rows x 178 columns]

# %% [markdown]
# ### Answering the Question, Again
#
# Now we can redo that plot without those negative heights:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

ax.scatter(
    x=question_2_df["Height"],
    y=question_2_df["Power Count"],
    alpha=0.3
)

ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count");

# %% [markdown]
# Ok, that makes more sense. It looks like there is not much of a relationship between height and number of superpowers.
#
# Now we can go on to answering the second half of question 2: *And does this differ based on gender?*
#
# To indicate multiple categories within a scatter plot, we can use color to add a third dimension:

# %%
# Run this cell without changes

fig, ax = plt.subplots(figsize=(16, 8))

# Select subsets
question_2_male = question_2_df[question_2_df["Gender"] == "Male"]
question_2_female = question_2_df[question_2_df["Gender"] == "Female"]
question_2_other = question_2_df[(question_2_df["Gender"] != "Male") & (question_2_df["Gender"] != "Female")]

# Plot data with different colors
ax.scatter(
    x=question_2_male["Height"],
    y=question_2_male["Power Count"],
    alpha=0.5,
    color="cyan",
    label="Male"
)
ax.scatter(
    x=question_2_female["Height"],
    y=question_2_female["Power Count"],
    alpha=0.5,
    color="gray",
    label="Female"
)
ax.scatter(
    x=question_2_other["Height"],
    y=question_2_other["Power Count"],
    alpha=0.5,
    color="yellow",
    label="Other"
)

# Customize appearance
ax.set_xlabel("Height (cm)")
ax.set_ylabel("Number of Superpowers")
ax.set_title("Height vs. Power Count")
ax.legend();

# %% [markdown]
# It appears that there is still no clear relationship between count of powers and height, regardless of gender. We do however note that "Male" is the most common gender, and that male superheroes tend to be taller, on average.

# %% [markdown]
# ## 4. Perform Data Aggregation Required to Answer Third Question
#
# Recall that the third question is: *What are the 5 most common superpowers in Marvel Comics vs. DC Comics?*
#
# We'll need to keep using `heroes_and_powers_df` since we require information from both `heroes_df` and `powers_df`.
#
# Your resulting `question_3_df` should contain aggregated data, with columns `Superpower Name`, `Marvel Comics` (containing the count of occurrences in Marvel Comics), and `DC Comics` (containing the count of occurrences in DC Comics). Each row should represent a superpower.
#
# In other words, `question_3_df` should look like this:
#
# ![question 3 df](images/question_3.png)
#
# Don't worry if the rows or columns are in a different order, all that matters is that you have the right rows and columns with all the data.
#
# ***Hint:*** refer to the [documentation for `.groupby`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html) and treat each publisher as a group.

# %%
publ_and_powers_df=heroes_and_powers_df.drop(['Gender','Eye color','Race','Hair color',
                                              'Height','Skin color','Alignment','Weight'],axis=1)
sum_of_powers=publ_and_powers_df.groupby('Publisher').sum()
question_3_df=sum_of_powers.transpose()
question_3_df=question_3_df.loc[:,['Marvel Comics','DC Comics']]
question_3_df.index.name = "Superpower Name"
question_3_df.reset_index(inplace=True)
question_3_df.drop(167,inplace=True)

# %% [markdown]
# The code below checks that you have the correct dataframe structure:

# %%
# Run this cell without changes

# Checking that you made a dataframe called question_3_df
assert type(question_3_df) == pd.DataFrame

# Checking the shape
assert question_3_df.shape == (167, 3)

# Checking the column names
assert sorted(list(question_3_df.columns)) == ['DC Comics', 'Marvel Comics', 'Superpower Name']

# %% [markdown]
# ### Answering the Question
#
# The code below uses the dataframe you created to find and plot the most common superpowers in Marvel Comics and DC Comics.

# %%
# Run this cell without changes

marvel_most_common = question_3_df.drop("DC Comics", axis=1)
marvel_most_common = marvel_most_common.sort_values(by="Marvel Comics", ascending=False)[:5]
marvel_most_common
# Out:
# Publisher Superpower Name  Marvel Comics
# 17         Super Strength          204.0
# 5              Durability          154.0
# 25                Stamina          150.0
# 30            Super Speed          137.0
# 0                 Agility          126.0

# %%
# Run this cell without changes

dc_most_common = question_3_df.drop("Marvel Comics", axis=1)
dc_most_common = dc_most_common.sort_values(by="DC Comics", ascending=False)[:5]
dc_most_common
# Out:
# Publisher Superpower Name  DC Comics
# 17         Super Strength      109.0
# 25                Stamina       90.0
# 8                  Flight       86.0
# 30            Super Speed       79.0
# 5              Durability       71.0

# %%
# Run this cell without changes

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(15, 5))

ax1.bar(
    x=marvel_most_common["Superpower Name"],
    height=marvel_most_common["Marvel Comics"]
)
ax2.bar(
    x=dc_most_common["Superpower Name"],
    height=dc_most_common["DC Comics"]
)

ax1.set_ylabel("Count of Superheroes")
ax2.set_ylabel("Count of Superheroes")
ax1.set_title("Frequency of Top Superpowers in Marvel Comics")
ax2.set_title("Frequency of Top Superpowers in DC Comics");

# %% [markdown]
# It looks like super strength is the most popular power in both Marvel Comics and DC Comics. Overall, the top 5 powers are fairly similar — 4 out of 5 overlap, although Marvel contains agility whereas DC contains flight.

# %% [markdown]
# ## 5. Formulate and Answer Your Own Question
#
# For the remainder of this lab, you'll be focusing on coming up with and answering your own question, just like we did above.  Your question should not be overly simple, and should require both descriptive statistics and data visualization to answer.  In case you're unsure of what questions to ask, some sample questions have been provided below.
#
# Pick one of the following questions to investigate and answer, or come up with one of your own!
#
# * Which powers have the highest chance of co-occurring in a hero (e.g. super strength and flight)?
# * What is the distribution of skin colors amongst alien heroes?
# * How are eye color and hair color related in this dataset?
#
# Explain your question below:

# %%
# Replace None with appropriate text:
"""
I am going to study the distribution of eye color and hair color in this data set, find out the most frequent for both
and making a scatter plot to see if there is a correlation between the two.
"""
# Out:
# '\nI am going to study the distribution of eye color and hair color in this data set, find out the most frequent for both\nand making a scatter plot to see if there is a correlation between the two.\n'

# %% [markdown]
# Some sample cells have been provided to give you room to work. Feel free to create more cells as needed.
#
# Be sure to include thoughtful, well-labeled visualizations to back up your analysis!
#
# (There is no solution branch for this part, and feel free to move on to the next lesson if you have already spent more than 90 minutes.)

# %%
hair_and_eye_df=heroes_df.drop(['Gender','Race','Height','Publisher','Skin color','Alignment','Weight'],axis=1)
hair_and_eye_df.head()
# Out:
#           name Eye color Hair color
# 0       A-Bomb    yellow    No Hair
# 1   Abe Sapien      blue    No Hair
# 2     Abin Sur      blue    No Hair
# 3  Abomination     green    No Hair
# 4      Abraxas      blue      Black

# %%
hair_and_eye_df['Eye color'].value_counts()
# Out:
# blue                       224
# -                          163
# brown                      123
# green                       73
# red                         46
# black                       22
# yellow                      18
# white                       17
# grey                         6
# hazel                        6
# purple                       4
# gold                         3
# amber                        2
# yellow (without irises)      2
# violet                       2
# silver                       1
# yellow / red                 1
# white / red                  1
# bown                         1
# blue / white                 1
# indigo                       1
# green / blue                 1
# yellow / blue                1
# Name: Eye color, dtype: int64

# %%
hair_and_eye_df['Hair color'].value_counts()
# Out:
# -                   163
# Black               154
# Blond                99
# Brown                85
# No Hair              74
# Red                  51
# White                23
# Auburn               13
# Green                 8
# Strawberry Blond      7
# Purple                5
# Grey                  5
# Silver                4
# Brown / White         4
# Blue                  3
# black                 3
# blond                 3
# Orange                2
# Yellow                2
# Red / White           1
# Magenta               1
# Black / Blue          1
# Red / Orange          1
# Red / Grey            1
# Brownn                1
# Pink                  1
# Indigo                1
# Orange / White        1
# Brown / Black         1
# Gold                  1
# Name: Hair color, dtype: int64

# %%
"""
From these two outputs we can get a sense of what is the distribution of the most common hair and eye color types.
Unfortunately, since the instances are not marked with a 1 of a True, I realized I cannot duse the method sum()
to be able to plot and do even more with this data, as the method sum just returns strings with all the names
od the super heroes with that specific color hair or eye.

But I can still do a scatter plot to see if there is a correlation/relation between the two.
"""
# Out:
# '\nFrom these two outputs we can get a sense of what is the distribution of the most common hair and eye color types.\nUnfortunately, since the instances are not marked with a 1 of a True, I realized I cannot duse the method sum()\nto be able to plot and do even more with this data, as the method sum just returns strings with all the names\nod the super heroes with that specific color hair or eye.\n\nBut I can still do a scatter plot to see if there is a correlation/relation between the two.\n'

# %%
#It is clear from the value counts that when the color was unknown a placeholder '-' was used. For the purporse
#of our analysis, im going to drop the columns that are marked as such.
hair_and_eye=hair_and_eye_df[hair_and_eye_df["Hair color"].str.contains("-")==False]

# %%
hair_and_eye['Hair color'].value_counts()
# Out:
# Black               154
# Blond                99
# Brown                85
# No Hair              74
# Red                  51
# White                23
# Auburn               13
# Green                 8
# Strawberry Blond      7
# Purple                5
# Grey                  5
# Brown / White         4
# Silver                4
# black                 3
# blond                 3
# Blue                  3
# Yellow                2
# Orange                2
# Gold                  1
# Indigo                1
# Pink                  1
# Orange / White        1
# Black / Blue          1
# Red / White           1
# Brown / Black         1
# Red / Orange          1
# Red / Grey            1
# Brownn                1
# Magenta               1
# Name: Hair color, dtype: int64

# %%
hair_and_eye['Eye color'].value_counts()
# Out:
# blue                       223
# brown                      122
# green                       73
# red                         41
# black                       20
# white                       17
# yellow                      15
# -                           14
# hazel                        6
# grey                         6
# gold                         3
# purple                       3
# yellow (without irises)      2
# violet                       2
# amber                        2
# indigo                       1
# green / blue                 1
# blue / white                 1
# yellow / blue                1
# bown                         1
# white / red                  1
# silver                       1
# Name: Eye color, dtype: int64

# %%
#clearly there are some repeated values because of different capitalization. Let me take care of that.
hair_and_eye['Eye color']=hair_and_eye['Eye color'].apply(lambda x : x.lower())
hair_and_eye['Hair color']=hair_and_eye['Hair color'].apply(lambda x : x.lower())
# Out:
# /Users/vi/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/vi/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
fig, ax = plt.subplots(figsize=(20, 8))

ax.scatter(
    x=hair_and_eye["Eye color"],
    y=hair_and_eye["Hair color"],
)
#ax.set_xticklabels(rotation=90)
ax.set_xlabel("Hair color")
ax.set_ylabel("Eye color")
ax.set_title("Hair and Eye color distribution");

# %%
# there doesn't seem to be a clear dependence between hair color and eye color.

# %% [markdown]
# ## Summary
#
# In this lab, you demonstrated your mastery of using pandas to clean and aggregate data in order to answer several business questions. This included identifying and handling missing values, text requiring preprocessing, and invalid values. You also performed aggregation and reshaping tasks such as transposing, joining, and grouping data. Great job, there was a lot here!
